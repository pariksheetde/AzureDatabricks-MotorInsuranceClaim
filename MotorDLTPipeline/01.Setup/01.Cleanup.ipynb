-- %% [markdown]
-- #### DROP INGESTION LAYER
-- - DROP BRONZE LAYERS TABLES

-- %%
DROP TABLE IF EXISTS MOTOR.BRONZE.INSURANCE_CLAIM_STREAM;
DROP TABLE IF EXISTS MOTOR.BRONZE.VEHICLE_ACCIDENTS_STREAM;

-- %% [markdown]
-- #### DROP TRANSFORMED LAYER
-- - DROP SILVER LAYERS TABLES

-- %%
DROP TABLE IF EXISTS MOTOR.SILVER.INSURANCE_CLAIM_TRANSFORMED;
DROP TABLE IF EXISTS MOTOR.SILVER.VEHICLE_ACCIDENTS_TRANSFORMED;
DROP TABLE IF EXISTS MOTOR.SILVER.VEHICLE_ACCIDENTS_QUARANTEED;
DROP TABLE IF EXISTS MOTOR.SILVER.VEHICLE_ACCIDENTS_IS_QUARANTEED;
DROP TABLE IF EXISTS MOTOR.SILVER.VEHICLE_ACCIDENTS_IS_NOT_QUARANTEED;

-- %% [markdown]
-- DROP `SLOWLY CHANGING DIMENSION TYPE 1` TABLE

-- %%
DROP TABLE IF EXISTS MOTOR.SILVER.ORDER_STATUS_RAW_SCD_1;
DROP TABLE IF EXISTS MOTOR.SILVER.ORDER_STATUS_STREAMING_SCD_1;
DROP TABLE IF EXISTS MOTOR.SILVER.ORDER_STATUS_SCD_1;

-- %% [markdown]
-- DROP `SLOWLY CHANGING DIMENSION TYPE 2` TABLE

-- %%
DROP TABLE IF EXISTS MOTOR.SILVER.ORDER_STATUS_RAW_SCD_2;
DROP TABLE IF EXISTS MOTOR.SILVER.ORDER_STATUS_STREAMING_SCD_2;
DROP TABLE IF EXISTS MOTOR.SILVER.ORDER_STATUS_SCD_2;

-- %% [markdown]
-- #### DROP ANALYTICS LAYER
-- - DROP GOLD LAYERS TABLES

-- %%
DROP TABLE IF EXISTS MOTOR.GOLD.HUMAN_INJURY_CASUALTIES;
DROP TABLE IF EXISTS MOTOR.GOLD.HUMAN_DEATH_CASUALTIES;

-- %%
%python
dbutils.notebook.exit("CLEANUP COMPLETED SUCCESSFULLY")
